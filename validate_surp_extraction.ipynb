# %%
import pandas as pd

ia_old = pd.read_csv('/data/home/shared/onestop/processed/ia_data_enriched_360_31032024.csv')

# %%
ia_new = pd.read_csv('/data/home/meiri.yoav/process-onestop-sr-report/ia_rep_180424.csv')

# %%
ia_old
# Out:
#          Unnamed: 0  TRIAL_INDEX  IA_AVERAGE_FIX_PUPIL_SIZE  IA_DWELL_TIME  \
# 0                 0           11                     1191.0            262
# 1                 1           11                        NaN              0
# 2                 2           11                        NaN              0
# 3                 3           11                     1243.0            155
# 4                 4           11                     1227.0            123
# ...             ...          ...                        ...            ...
# 2532794     2532794           69                        NaN              0
# 2532795     2532795           69                        NaN              0
# 2532796     2532796           69                      602.0            182
# 2532797     2532797           69                        NaN              0
# 2532798     2532798           69                        NaN              0
#
#          IA_DWELL_TIME_%  IA_FIRST_FIXATION_DURATION  \
# ...

# %%
ia_new
# Out:
#          Unnamed: 0  TRIAL_INDEX  IA_AVERAGE_FIX_PUPIL_SIZE  IA_DWELL_TIME  \
# 0                 0            1                     1092.0            237
# 1                 1            1                     1097.0            174
# 2                 2            1                      991.5            336
# 3                 3            1                        NaN              0
# 4                 4            1                     1055.5            268
# ...             ...          ...                        ...            ...
# 2632154     2632154           72                        NaN              0
# 2632155     2632155           72                        NaN              0
# 2632156     2632156           72                      516.0            234
# 2632157     2632157           72                        NaN              0
# 2632158     2632158           72                        NaN              0
#
#          IA_DWELL_TIME_%  IA_FIRST_FIXATION_DURATION  \
# ...
